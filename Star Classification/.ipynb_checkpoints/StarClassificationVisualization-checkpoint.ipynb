# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
FACECOLOR = "#f6f6f6"

colors = ["#cf1313","#13a6cf","#f5f3ed","#fff373","#f2bd6d","#1358cf"]
sns.set_theme(style="ticks")
sns.set_palette(sns.color_palette(colors))

# %%
df = pd.read_csv("Stars.csv")

# %%
df.head()
# Out:
#    Temperature         L       R    A_M Color Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12   Red              M     0
# 1         3042  0.000500  0.1542  16.60   Red              M     0
# 2         2600  0.000300  0.1020  18.70   Red              M     0
# 3         2800  0.000200  0.1600  16.65   Red              M     0
# 4         1939  0.000138  0.1030  20.06   Red              M     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature     240 non-null    int64
#  1   L               240 non-null    float64
#  2   R               240 non-null    float64
#  3   A_M             240 non-null    float64
#  4   Color           240 non-null    object
#  5   Spectral_Class  240 non-null    object
#  6   Type            240 non-null    int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.2+ KB

# %%
df.describe()
# Out:
#         Temperature              L            R         A_M        Type
# count    240.000000     240.000000   240.000000  240.000000  240.000000
# mean   10497.462500  107188.361635   237.157781    4.382396    2.500000
# std     9552.425037  179432.244940   517.155763   10.532512    1.711394
# min     1939.000000       0.000080     0.008400  -11.920000    0.000000
# 25%     3344.250000       0.000865     0.102750   -6.232500    1.000000
# 50%     5776.000000       0.070500     0.762500    8.313000    2.500000
# 75%    15055.500000  198050.000000    42.750000   13.697500    4.000000
# max    40000.000000  849420.000000  1948.500000   20.060000    5.000000

# %%
df["Color"].value_counts()
# Out:
# Red                   112
# Blue                   56
# Blue-white             26
# Blue White             10
# yellow-white            8
# White                   7
# Blue white              4
# Yellowish White         3
# white                   3
# Whitish                 2
# Orange                  2
# yellowish               2
# White-Yellow            1
# Pale yellow orange      1
# Orange-Red              1
# Yellowish               1
# Blue-White              1
# Name: Color, dtype: int64

# %%
def color_name_fix(color):
    if "orange" in color.lower():
        color = "Orange"
    elif "yellow" in color.lower():
        color = "Yellowish"
    elif color.lower() == "whitish":
        color = "White"
    else:
        color = color.replace("-"," ")
        color = color.title()
        color = color.replace(" ","-")
    return color

# %%
df["Color"] = df["Color"].apply(color_name_fix)

# %%
df.head()
# Out:
#    Temperature         L       R    A_M Color Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12   Red              M     0
# 1         3042  0.000500  0.1542  16.60   Red              M     0
# 2         2600  0.000300  0.1020  18.70   Red              M     0
# 3         2800  0.000200  0.1600  16.65   Red              M     0
# 4         1939  0.000138  0.1030  20.06   Red              M     0

# %%
sns.countplot(df["Type"])
# Out:
# c:\users\merts\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
df["Color"].value_counts()
# Out:
# Red           112
# Blue           56
# Blue-White     41
# Yellowish      15
# White          12
# Orange          4
# Name: Color, dtype: int64

# %%
fig = plt.figure(figsize = (12,12), facecolor= FACECOLOR)
ax = fig.add_subplot()
color_palette = ["#cf1313","#1358cf","#13a6cf","#fff373","#f5f3ed","#f2bd6d"]
labels = ["Red","Blue","Blue-White","Yellowish","White","Orange"]
explode = (0.01,0.01,0.01,0.01,0.01,0.01)

ax.pie(df["Color"].value_counts(), colors = color_palette, autopct='%1.1f%%', explode = explode,shadow=True,textprops={'fontsize': 14})
ax.text(-0.8,1.2,"Color Distributions of Observed Stars", fontsize=20,fontweight = "bold", fontfamily ="serif")
# Out:
# Text(-0.8, 1.2, 'Color Distributions of Observed Stars')

# %%
fig = plt.figure(figsize = (12,12), facecolor= FACECOLOR)
ax = fig.add_subplot()
color_palette = ["#cf1313","#1358cf","#13a6cf","#fff373","#f5f3ed","#f2bd6d"]
labels = ["Red","Blue","Blue-White","Yellowish","White","Orange"]
wedges, texts,_ = ax.pie(df["Color"].value_counts(),autopct='%1.1f%%',pctdistance=0.45,textprops={'fontsize': 20}, wedgeprops=dict(width=0.4,edgecolor="k",linewidth = 2), colors = color_palette)
bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="gray", lw=0.8, ls =":")
kw = dict(arrowprops=dict(arrowstyle="->", color="0.3",shrinkA=5, shrinkB=5,),
          bbox=bbox_props, zorder=0, va="center", size = 20)

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    count = df[df["Color"]==labels[i]]["Color"].count()
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(f"{count} {labels[i]} Stars" , xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.text(-1.4,1.6,"Color Distributions of Observed Stars", fontsize=36,fontweight = "bold", fontfamily ="serif")        
ax.text(-0.2,-0.05,"Colors",fontsize=28, fontweight = "bold", fontfamily ="serif")
# Out:
# Text(-0.2, -0.05, 'Colors')

# %%
desc = {"M":"Strong titanium oxide and some calcium.",
       "B":"Helium, some hydrogen.",
       "O":"Ionized helium, especially helium.",
       "A":"Strong hydrogen, some ionized metal.",
       "F":"Hydrogen and ionized metals \nsuch as calcium and iron.",
       "K":"Metals",
       "G":"Both metals and ionized metals, \nespecially ionized calcium."}

# %%
color_palette_spectral = ["#cf1313","#1358cf","#13a6cf","#f5d782","#ede2a8","#f6f6f6","#f2a154"]
labels_spectral = ["M","B","O","A","F","K","G"]

fig2 = plt.figure(figsize = (12,12), facecolor= "#f6f6f6")
ax2 = fig2.add_subplot()
explode = (0.01,0.01,0.01,0.01,0.01,0.01,0.01)

ax2.pie(df["Spectral_Class"].value_counts(), labels = labels_spectral, colors = color_palette_spectral, 
        autopct='%1.1f%%', textprops={'fontsize': 20}, wedgeprops=dict(width=1, edgecolor='w'))
ax2.text(-0.7,1.3,"Spectral Class Distributions of Observed Stars", fontsize=28,
         style = "oblique", fontweight = "bold", fontfamily ="serif")
ax2.text(-0.7, 1.2, "*with relative colorization.",fontsize = 20, fontfamily="serif")
ax2.text(1.7,0.95,"Spectral Features:",fontsize=24,fontweight = "bold", fontfamily ="monospace")
ax2.text(1.5, 0.65,"M :",fontsize=24,fontweight = "bold", fontfamily ="serif")
ax2.text(1.7, 0.65,desc["M"],fontsize = 20)
ax2.text(1.5, 0.45,"B :",fontsize=24,fontweight = "bold", fontfamily ="serif")
ax2.text(1.7, 0.45,desc["B"],fontsize = 20)
ax2.text(1.5, 0.25,"O :",fontsize=24,fontweight = "bold", fontfamily ="serif")
ax2.text(1.7, 0.25,desc["O"],fontsize = 20)
ax2.text(1.5, 0.05,"A :",fontsize=24,fontweight = "bold", fontfamily ="serif")
ax2.text(1.7, 0.05,desc["A"],fontsize = 20)
ax2.text(1.5, -0.15,"F :",fontsize=24,fontweight = "bold", fontfamily ="serif")
ax2.text(1.7, -0.2,desc["F"],fontsize = 20)
ax2.text(1.5, -0.35,"K :", fontsize=24,fontweight = "bold", fontfamily ="serif")
ax2.text(1.7, -0.35,desc["K"],fontsize = 20)
ax2.text(1.5, -0.55,"G :",fontsize=24,fontweight = "bold", fontfamily ="serif")
ax2.text(1.7, -0.6,desc["G"],fontsize = 20)
# Out:
# Text(1.7, -0.6, 'Both metals and ionized metals, \nespecially ionized calcium.')

# %%
color_palette = ["#cf1313","#1358cf","#13a6cf","#fff373","#f5f3ed","#f2bd6d"]
labels = ["Red","Blue","Blue-White","Yellowish","White","Orange"]

color_palette_spectral = ["#cf1313","#1358cf","#13a6cf","#f5d782","#faeda7","#f6f6f6","#f2a154"]
labels_spectral = ["M","B","O","A","F","K","G"]

fig = plt.figure(figsize = (12,12), facecolor= "#f6f6f6")
ax = fig.add_subplot()

ax.pie(df["Spectral_Class"].value_counts(), radius = 1, colors = color_palette_spectral,
      wedgeprops=dict(width=0.3, edgecolor='w'), labels = labels_spectral,
        textprops={'fontsize': 14})
ax.pie(df["Color"].value_counts(),radius = 1-0.3, colors = color_palette,
      wedgeprops=dict(width=0.3, edgecolor='w'))
ax.text(-1.2,1.2,"Spectral Class and Color Distributions Drawn Together", fontsize=20,fontweight = "bold", fontfamily ="serif")
ax.text(-0.1,-0.02,"Colors",fontsize= 18)
ax.text(-1,0.9,"Spectral Class",fontsize= 18)
ax.set(aspect = "equal")
# Out:
# [None]

# %%
fig = plt.figure(figsize=(12, 6),facecolor = FACECOLOR)

colors = ["#cf1313","#13a6cf","#f5f3ed","#fff373","#f2bd6d","#1358cf"]
#sns.set(rc={'figure.figsize':(20,20)})
sns.set_theme(style="ticks")
sns.set_palette(sns.color_palette(colors))

ax1 = fig.add_subplot(121)
g = sns.stripplot( x = "Spectral_Class", y = "Type", data = df,hue = "Color", ax = ax1)
ax1.set_title("Spectral Class")
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

# %%
colors = ["#cf1313","#13a6cf","#f5f3ed","#fff373","#f2bd6d","#1358cf"]
sns.set(rc={'figure.figsize':(12,12)})
sns.set_theme(style="ticks")
sns.set_palette(sns.color_palette(colors))
sns.catplot(x = "Type", y = "Temperature", data = df, hue = "Color")

# %%
colors = ["#cf1313","#13a6cf","#f5f3ed","#fff373","#f2bd6d","#1358cf"]
sns.set(rc={'figure.figsize':(12,12)})
sns.set_theme(style="ticks")
sns.set_palette(sns.color_palette(colors))
sns.catplot(x = "Type", y = "L", data = df, hue = "Color")

# %%
colors = ["#cf1313","#13a6cf","#f5f3ed","#fff373","#f2bd6d","#1358cf"]
sns.set(rc={'figure.figsize':(12,12)})
sns.set_theme(style="ticks")
sns.set_palette(sns.color_palette(colors))
sns.catplot(x = "Type", y = "R", data = df, hue = "Color")

# %%
colors = ["#cf1313","#13a6cf","#f5f3ed","#fff373","#f2bd6d","#1358cf"]
sns.set(rc={'figure.figsize':(12,12)})
sns.set_theme(style="ticks")
sns.set_palette(sns.color_palette(colors))
sns.catplot(x = "Type", y = "A_M", data = df, hue = "Color")

# %%
sns.pairplot(df,hue = "Type")

# %%
import matplotlib
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.set_facecolor("#f6f6f6") 
corr = df.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

colors = ["#cf1313","lightgray", "#1358cf"]
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)

sns.heatmap(corr, 
            square=True, 
            mask=mask,
            linewidth=2.5, 
            vmax=0.4, vmin=-0.4, 
            cmap=cmap, 
            cbar=False, 
            ax=ax,annot=True)

ax.set_yticklabels(ax.get_xticklabels(), fontfamily='serif', rotation = 0, fontsize=11)
ax.set_xticklabels(ax.get_xticklabels(), fontfamily='serif', rotation=90, fontsize=11)

ax.spines['top'].set_visible(True)

plt.tight_layout()
plt.show()

# %%
class customEncoder:
    
    _type_decoder = {
        0 : "Red Dwarf",
        1 : "Brown Dwarf", 
        2 : "White Dwarf", 
        3 : "Main Sequence",
        4 : "Super Giants" ,
        5 : "Hyper Giants" 
    }
    
    def __init__(self):
        self.enc_map = dict()
        self.decoded_data = None
        self._encoded = False
    def fit(self,data):
        self.data = data
    def encode(self):
        if not self._encoded:
            self._encoded = True
            for i,col in enumerate(self.data.columns):
                if self.data[col].dtypes == "object":
                    n_ins = self.data[col].nunique()
                    dict_to_map = dict(zip(self.data[col].unique(), range(n_ins)))
                    self.enc_map[col] = dict_to_map
                    self.data[col] = self.data[col].map(dict_to_map)
                    
    def fit_encode(self,data):
        self.fit(data)
        self.encode()
        
    def decode_target(self):
        if not self.decoded_data:
            self.decoded_data = self.data.copy()
            self.decoded_data["Type"] = self.decoded_data["Type"].map(self._type_decoder)
    
    def decode(self):
        if self._encoded:
            for col in self.enc_map.keys():
                decode_map = dict(zip(self.enc_map[col].values(),self.enc_map[col].keys()))
                self.data[col] = self.data[col].map(decode_map)
            self._encoded = False

# %%
cenc = customEncoder()
cenc.fit_encode(df)

# %%
import matplotlib
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.set_facecolor("#f6f6f6") 
corr = df.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

colors = ["#cf1313","lightgray", "#1358cf"]
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)

sns.heatmap(corr, 
            square=True, 
            mask=mask,
            linewidth=2.5, 
            vmax=0.4, vmin=-0.4, 
            cmap=cmap, 
            cbar=False, 
            ax=ax,annot=True)

ax.set_yticklabels(ax.get_xticklabels(), fontfamily='serif', rotation = 0, fontsize=11)
ax.set_xticklabels(ax.get_xticklabels(), fontfamily='serif', rotation=90, fontsize=11)

ax.spines['top'].set_visible(True)

plt.tight_layout()
plt.show()
